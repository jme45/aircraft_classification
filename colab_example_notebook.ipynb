# %%
# %%shell
# git clone https://github.com/jme45/aircraft_classification.git
# git clone https://github.com/jme45/ml_utils.git ml_utils_colab
# mv aircraft_classification/* .
# mv ml_utils_colab/ml_utils/ .
# pip install -q -r requirements.txt
# Out:
# Cloning into 'aircraft_classification'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 58 (delta 30), reused 48 (delta 20), pack-reused 0
# Receiving objects: 100% (58/58), 18.08 KiB | 2.58 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# Cloning into 'ml_utils_colab'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 66 (delta 22), reused 59 (delta 15), pack-reused 0
# Receiving objects: 100% (66/66), 13.42 KiB | 6.71 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
import fit_model
import download_and_prepare_dataset

# %%
download_and_prepare_dataset.run_downloads()
# Out:
# ...
# 100%|██████████| 2753340328/2753340328 [01:15<00:00, 36377176.13it/s]
# Extracting data/fgvc-aircraft-2013b.tar.gz to data
# ...
# Extracting targets:   0%|          | 0/105 [00:00<?, ?it/s]

# %%
save_in_drive = False
if save_in_drive:
  from google.colab import drive
  drive.mount('/content/gdrive')

# %%
if save_in_drive:
  output_path =  "/content/gdrive/MyDrive/ml_files/aircraft_classification"
else:
  output_path = "runs/aircraft_classification"

# %%
import fit_model

# %%
fit_model.fit_model('trivial', 'test', 3, output_path, num_workers=2)
# Out:
# ...
# Testing epoch 2:   0%|          | 0/7 [00:00<?, ?it/s]
# ({'train_loss': [0.036976843774318695,
#    0.03247243106365204,
#    0.03312995553016663],
#   'test_loss': [0.03422368136211414, 0.035495459143795184, 0.0357162970215527],
#   'train_Accuracy': [0.5099999904632568,
#    0.6650000214576721,
#    0.6650000214576721],
#   'train_F1Score': [0.5099999904632568,
#    0.6650000214576721,
#    0.6650000214576721],
#   'train_epoch_time': [11.328084031999992,
#    7.89337522400001,
#    8.526787014999968],
#   'test_Accuracy': [0.6666666865348816,
#    0.6666666865348816,
#    0.6666666865348816],
#   'test_F1Score': [0.6666666865348816, 0.6666666865348816, 0.6666666865348816],
#   'test_epoch_time': [4.656439940999917,
#    4.058380808999914,
#    4.071250677999956]},
#  {'num_params': 579,
#   'output_path': '/content/gdrive/MyDrive/ml_files/aircraft_classification/test/test/trivial/2023-12-14_13-22'})
