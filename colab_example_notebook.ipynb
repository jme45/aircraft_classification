# %%
# !pip install -q git+https://github.com/jme45/aircraft_classification.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 8.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import aircraft_classification

# %%
from aircraft_classification import fit_model, download_and_prepare_dataset

# %%
download_and_prepare_dataset.run_downloads()
# Out:
# ...
# 100%|██████████| 2753340328/2753340328 [02:09<00:00, 21271611.77it/s]
# Extracting /usr/local/lib/python3.10/data/fgvc-aircraft-2013b.tar.gz to /usr/local/lib/python3.10/data
# ...
# Extracting targets:   0%|          | 0/105 [00:00<?, ?it/s]

# %%
fit_model.fit_model('trivial', 'test', 2,)
# Out:
# ...
# Testing epoch 1:   0%|          | 0/7 [00:00<?, ?it/s]
# [{'train_loss': [0.032666003108024595, 0.03465673744678497],
#   'test_loss': [0.0351303058180643, 0.03469566444852459],
#   'train_Accuracy': [0.6650000214576721, 0.6650000214576721],
#   'train_F1Score': [0.6650000214576721, 0.6650000214576721],
#   'train_epoch_time': [10.189726772999961, 9.001995649000037],
#   'test_Accuracy': [0.6666666865348816, 0.6666666865348816],
#   'test_F1Score': [0.6666666865348816, 0.6666666865348816],
#   'test_epoch_time': [4.20616561199995, 4.4038766380000425]},
#  {'num_params': 579,
#   'output_path': '/usr/local/lib/python3.10/runs/test/test/trivial/2024-01-24_11-51'}]
